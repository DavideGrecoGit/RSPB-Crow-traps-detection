# %% [markdown]
# # Train

# %%
from ultralytics import YOLO

model_path = "runs/detect/train_50/weights/best.pt"
data_path = "Datasets/Crow_detection_train/config.yaml"

model = YOLO(model_path)  # load model 

# Train the model
valid_results = model.train(
   data=data_path, epochs=50, imgsz=224,hsv_h=0.015,hsv_s=0.7,hsv_v=0.4, fliplr=0.5, flipud=0.5
)
print(valid_results)
# Out:
# New https://pypi.org/project/ultralytics/8.0.208 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.193 🚀 Python-3.11.5 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce GTX 1060 6GB, 6070MiB)
# ...

# %% [markdown]
# # Test

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO("runs/detect/train_50/weights/best.pt")
source = "Datasets/Crow_detection/test/crow_trap"

# Run inference on 'bus.jpg' with arguments
results = model.predict(source, save=False, imgsz=224, conf=0.5)

sum = 0
for result in results:
    if len(result.boxes.cpu().numpy()) > 0:
        sum = sum + 1

print(sum/len(results))
# Out:
# image 1/45 /home/davide/Desktop/Projects/RSPB-Crow-traps-detection/Datasets/Crow_detection/test/crow_trap/100331_2_1.jpeg: 224x224 (no detections), 5.8ms
# image 2/45 /home/davide/Desktop/Projects/RSPB-Crow-traps-detection/Datasets/Crow_detection/test/crow_trap/100459_2_1.jpeg: 224x224 1 crow_trap, 6.6ms
# image 3/45 /home/davide/Desktop/Projects/RSPB-Crow-traps-detection/Datasets/Crow_detection/test/crow_trap/100563_1_0.jpeg: 224x224 1 crow_trap, 5.6ms
# image 4/45 /home/davide/Desktop/Projects/RSPB-Crow-traps-detection/Datasets/Crow_detection/test/crow_trap/100615_2_1.jpeg: 224x224 1 crow_trap, 5.6ms
# image 5/45 /home/davide/Desktop/Projects/RSPB-Crow-traps-detection/Datasets/Crow_detection/test/crow_trap/100631_2_1.jpeg: 224x224 1 crow_trap, 5.8ms
# image 6/45 /home/davide/Desktop/Projects/RSPB-Crow-traps-detection/Datasets/Crow_detection/test/crow_trap/100980_2_1.jpeg: 224x224 1 crow_trap, 6.3ms
# ...

# %%
# Out:
# 0.6222222222222222

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO("runs/detect/train_50/weights/best.pt")
source = "Datasets/Crow_detection/test/background"

# Run inference on 'bus.jpg' with arguments
results_back = model.predict(source, save=True, imgsz=224, conf=0.5)

sum = 0
for result in results_back:
    if len(result.boxes.cpu().numpy()) > 0:
        sum = sum + 1

print(sum/len(results_back))
# Out:
# image 1/97 /home/davide/Desktop/Projects/RSPB-Crow-traps-detection/Datasets/Crow_detection/test/background/100331_0_2.jpeg: 224x224 (no detections), 5.5ms
# image 2/97 /home/davide/Desktop/Projects/RSPB-Crow-traps-detection/Datasets/Crow_detection/test/background/100331_1_1.jpeg: 224x224 (no detections), 5.7ms
# image 3/97 /home/davide/Desktop/Projects/RSPB-Crow-traps-detection/Datasets/Crow_detection/test/background/100331_2_0.jpeg: 224x224 (no detections), 5.9ms
# image 4/97 /home/davide/Desktop/Projects/RSPB-Crow-traps-detection/Datasets/Crow_detection/test/background/100331_2_2.jpeg: 224x224 (no detections), 5.6ms
# image 5/97 /home/davide/Desktop/Projects/RSPB-Crow-traps-detection/Datasets/Crow_detection/test/background/100331_3_1.jpeg: 224x224 (no detections), 5.8ms
# image 6/97 /home/davide/Desktop/Projects/RSPB-Crow-traps-detection/Datasets/Crow_detection/test/background/100459_1_0.jpeg: 224x224 (no detections), 5.5ms
# ...

# %%
# Out:
# 0.06666666666666667
