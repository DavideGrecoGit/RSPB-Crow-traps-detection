# %% [markdown]
# #### Colored images

# %%
from ultralytics import YOLO

model_path = "yolov8n-cls.pt"
data_path = "Datasets/Crow_classify"

model = YOLO(model_path)  # load model 

# Train the model
valid_results = model.train(
   data=data_path, epochs=10, imgsz=224,hsv_h=0.015,hsv_s=0.7,hsv_v=0.4, fliplr=0.5, flipud=0.5
)
print(valid_results)
# Out:
# New https://pypi.org/project/ultralytics/8.0.201 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.193 🚀 Python-3.11.5 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce GTX 1060 6GB, 6070MiB)
# ...

# %%
model.val(data="Datasets/Crow_evaluate_classify")
# Out:
# Ultralytics YOLOv8.0.193 🚀 Python-3.11.5 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce GTX 1060 6GB, 6070MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients, 3.3 GFLOPs
# train: /home/davide/Desktop/Projects/RSPB/Datasets/Crow_evaluate_classify/train... found 730 images in 2 classes ✅
# val: /home/davide/Desktop/Projects/RSPB/Datasets/Crow_evaluate_classify/val... found 106 images in 2 classes ✅
# test: None...
# val: Scanning /home/davide/Desktop/Projects/RSPB/Datasets/Crow_evaluate_classify/val... 106 images, 0 corrupt: 100%|██████████| 106/106 [00:00<00:00, 3943.73it/s]
# val: New cache created: /home/davide/Desktop/Projects/RSPB/Datasets/Crow_evaluate_classify/val.cache
#                classes   top1_acc   top5_acc: 100%|██████████| 7/7 [00:00<00:00, 13.07it/s]
#                    all      0.943          1
# Speed: 0.1ms preprocess, 2.2ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/val
# ...

# %% [markdown]
# #### Grey Images

# %%
from ultralytics import YOLO

model_path = "yolov8n-cls.pt"
data_path = "Datasets/Crow_classify_grey"

model = YOLO(model_path)  # load model 

# Train the model
valid_results = model.train(
   data=data_path, epochs=10, imgsz=224,hsv_h=0.015,hsv_s=0.7,hsv_v=0.4, fliplr=0.5, flipud=0.5
)
print(valid_results)
# Out:
# New https://pypi.org/project/ultralytics/8.0.201 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.193 🚀 Python-3.11.5 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce GTX 1060 6GB, 6070MiB)
# ...

# %%
model.val(data="Datasets/Crow_evaluate_classify_grey")
# Out:
# Ultralytics YOLOv8.0.193 🚀 Python-3.11.5 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce GTX 1060 6GB, 6070MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients, 3.3 GFLOPs
# train: /home/davide/Desktop/Projects/RSPB/Datasets/Crow_evaluate_classify_grey/train... found 730 images in 2 classes ✅
# val: /home/davide/Desktop/Projects/RSPB/Datasets/Crow_evaluate_classify_grey/val... found 106 images in 2 classes ✅
# test: None...
# val: Scanning /home/davide/Desktop/Projects/RSPB/Datasets/Crow_evaluate_classify_grey/val... 106 images, 0 corrupt: 100%|██████████| 106/106 [00:00<00:00, 4031.05it/s]
# val: New cache created: /home/davide/Desktop/Projects/RSPB/Datasets/Crow_evaluate_classify_grey/val.cache
#                classes   top1_acc   top5_acc: 100%|██████████| 7/7 [00:00<00:00, 12.48it/s]
#                    all      0.811          1
# Speed: 0.2ms preprocess, 2.4ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/val2
# ...
